# %% [markdown]
# ### DATA MANIPULATION

# %% [markdown]
# * Changing data
# * Updating data
# * Removing data
# * Adding data

# %%
import pandas as pd 

data = {
    "Name" : ["A","B","C"],
    "Age" : [21,22,23]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Name  Age
# 0    A   21
# 1    B   22
# 2    C   23

# %% [markdown]
# ### ADD NEW COLUMN

# %%
## add a new column salary

df["Salary"] = [5000,6000,7000]

print(df)
# Out:
#   Name  Age  Salary
# 0    A   21    5000
# 1    B   22    6000
# 2    C   23    7000

# %% [markdown]
# ### UPDATE EXISTING VALUES

# %%
df["Age"] = df["Age"] + 10

print(df)
# Out:
#   Name  Age  Salary
# 0    A   32    5000
# 1    B   33    6000
# 2    C   34    7000

# %% [markdown]
# ### DROP A COLUMN

# %%
## TEMPERORY DROP

df.drop("Salary",axis=1)

## axis = 1 means
## Column operation is not permanent yet
# Out:
#   Name  Age
# 0    A   32
# 1    B   33
# 2    C   34

# %%
## PERMANENT DROP

df.drop("Salary", axis=1, inplace = True)

# now permanently removed

print(df)
# Out:
#   Name  Age
# 0    A   32
# 1    B   33
# 2    C   34

# %%
df.drop(0, inplace=True)

print(df)
# Out:
#   Name  Age
# 1    B   33
# 2    C   34
