# %% [markdown]
# # JSON OPERATIONS

# %% [markdown]
# #### what is json?
# * Json = Javascript Object Notation
#     * a lightweight data format
#     * used to store and exchange data
#
# * JSON STORES DATA AS
#     * {
#         "key" : "Value"
#     }
#
#     * Very common in APIs , WebApps , Backend systems

# %%
## What problem JSON solves 

## imagine this in python

name = "Aksa"

age = 22

role = "Data Analyst"

# %% [markdown]
# ### Now suppose :
# * website wants data
# * backend wants data
# * API wants data
# * ------------------------- So sending 3 separate variables is kinda messy (So we package them together)
#
# ## JSON is just a PACKET of data

# %%
## Like this :

{
    "name" : "Aksa",
    "age" : 22,
    "role" : "Data Analyst"
}

## THIS IS JSON


##-------------- JSON STRUCTURE -----------------------

# left side = "name" -- mainly KEYS
# right side = "Aksa" -- Values

# Label : actual data

# %% [markdown]
# #### Why industry loves JSON
# * Because:
#     * humans and machines can read it
#     * works eveywhere
#
# * Used in :
#     * APIs
#     * WebApps
#     * MobileApps
#     * DB
#     * AI systems
#
# ### JSON IS NOT PANDAS
#
# ### IT IS SIMPLY A DATA FORMAT pandas simply reads it.
#
# * Excel file → Pandas reads
# * CSV file → Pandas reads
# * JSON file → Pandas reads

# %% [markdown]
# * JSON = container of data
# * Pandas = tool that reads container

# %% [markdown]
# ## Why Lists Are Used in JSON for Pandas
#
# * Becuase Pandas wants Columns of data
# * Json stores them as lists.
#
#     * Each list must have same number of items
#     * JSON LISTS = PANDAS COLUMNS
#     * LIST ITEMS = ROW VALUES

# %%
################################################################

# %% [markdown]
# # pd.read_json()
# * Converts json to Data Frame

# %%
import pandas as pd
from io import StringIO

data = '''
{
  "name": ["Aksa", "John"],
  "age": [21, 25]
}
'''
df = pd.read_json(StringIO(data))
print(df)
# Out:
#    name  age
# 0  Aksa   21
# 1  John   25
