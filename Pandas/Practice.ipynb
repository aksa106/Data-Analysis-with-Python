# %%
import pandas as pd

# %%
## CREATE A SERIES

s = [10,20,30]
pd.Series(s)

print(s)
# Out:
# [10, 20, 30]

# %%
## CREATING A DATA FRAME 

data = {
    'Name' : ['X','Y','Z'], 
    'Age'  : [12,12,14]
}

Data_Frame = pd.DataFrame(data)

print(Data_Frame)
# Out:
#   Name  Age
# 0    X   12
# 1    Y   12
# 2    Z   14
