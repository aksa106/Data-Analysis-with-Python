# %% [markdown]
# # Data Inspection Mastery

# %% [markdown]
# #### Open an unknown data set and understand it in two minutes

# %%
import seaborn as sns 

tips = sns.load_dataset("tips")

print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
#     Task 1
#
#     How many rows and columns are there?
#     What are the column names?
#     Which columns are numerical?
#     Which columns are categorical?
#     Which column would you predict is the target/business outcome column?

# %%
## how many rows and columns are there

import seaborn as sns , pandas as pd

tips = sns.load_dataset("tips")


## Finding out how many rows and columns are there

print(f"Information \n {tips.info()}")

print(tips.shape)

## Total rows : 6
## Total Columns : 244

print()

##Column names

print(f"Column names \n{tips.columns}")

print()

## Which columns are numerical

## total_bill, tip,  size


### Which columns are categorical?
## time, day, sex , smoker


###Which column would you predict is the target/business outcome column?

## totalbill and tip
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# Information
#  None
# (244, 7)
#
# Column names
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
#     Task 2 — Inspect Like an Analyst
#
#     Using only:
#
#     info()
#     describe()
#
#     Answer these questions:
#
#     From info()
#     Are there any missing values?
#     Which column uses the most memory?
#     Which columns are stored as categories?
#     From describe()
#     What is the average total_bill?
#     What is the largest tip?
#     What is the smallest party size?
#     Which numerical column appears to have the largest spread/variability?
#     Think Like an Analyst
#
#     After looking at describe(), answer:
#
#     Which numerical column would you investigate first?
#
#     Reason:

# %%
# From info()

import seaborn as sns , pandas as pd

tips = sns.load_dataset("tips")

# Are there any missing values?

tips.info()

# Which column uses the most memory?
##


# Which columns are stored as categories?
## sex smoker day time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# From describe()


import seaborn as sns , pandas as pd

tips = sns.load_dataset("tips")


tips.describe()


# What is the average total_bill?
## 19.785943


# What is the largest tip?
## 10.000000	


# What is the smallest party size?
## 1.000000

# Which numerical column appears to have the largest spread/variability?
## total_bill (range - 3-50)
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
