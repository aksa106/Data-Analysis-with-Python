# %% [markdown]
# # EDA

# %% [markdown]
# ### Customer analysis
# * Gender
#     * Customer Count by Gender
#     * Total Sales by Gender
# * Age
#             Customer Distribution by Age
#             Total Sales by Age
#             Orders by Age (optional)
#
# ### Geographical Analysis
# * State
#         Customer Count by State
#         Total Orders by State
#         Total Sales by State
#
# ### Product Analysis
#
# * Product
#         Product Purchase Count
#         Total Orders by Product
#         Total Sales by Product
#
# * Product Category
#         Product Category Count
#         Total Sales by Category
#         Total Orders by Category
#
# ### Sales Analysis
# * Payment Mode
#         Payment Mode Distribution
#         Total Sales by Payment Mode
#
# * Order Month
#         Orders by Month
#         Sales by Month
#
# ### Top Performers
# * Top Selling Products
#         Top Products by Orders
#         Top Products by Revenue
#
# * Top Performing States
#         Top States by Orders
#         Top States by Revenue
#
#
#         Primary Customer Segment
#         Highest Revenue Source
#         Best Performing Product Category
#         Best Performing Product
#         Best Performing State
#         Most Preferred Payment Mode
#         Monthly Sales Trend
#         Key Business Recommendations

# %% [markdown]
# # Customer Analysis

# %% [markdown]
# ### Gender

# %%
## Analyze the gender distribution of customers and compare their purchasing behavior.

# %%
import pandas as pd 

import numpy as np 

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv('Clean_Data.csv')

# %% [markdown]
# #### Customer Count by Gender

# %%
## Determine the number of males and females customers 

# before analyzing which gender is contributing more to sales , we are first gonna ask, how many customer belong to each gender by frequency analysis.

## We are going to use a count plot 

## count plot : automatically counts the frequency of every category, we dont need to use groupby because seaborn counts for us.

plt.figure(figsize)
