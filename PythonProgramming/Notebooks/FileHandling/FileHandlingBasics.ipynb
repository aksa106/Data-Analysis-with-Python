# %% [markdown]
# # File Handling

# %% [markdown]
# * Introduction
# * Opening and Closing
# * Reading
# * Writing
# * File Pointer
# * Combined Practice

# %% [markdown]
# ##### Introduction

# %% [markdown]
# #### Imagine writing Python without Files
